# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.17.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting urllib3<3,>=1.26 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting certifi>=2021.10.8 (from selenium)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting typing_extensions>=4.9.0 (from selenium)
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting attrs>=20.1.0 (from trio~=0.17->selenium)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting idna (from trio~=0.17->selenium)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting cffi>=1.14 (from trio~=0.17->selenium)
#   Using cached cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pycparser (from cffi>=1.14->trio~=0.17->selenium)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading selenium-4.17.2-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.9 MB 1.7 MB/s eta 0:00:06
#     --------------------------------------- 0.1/9.9 MB 1.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/9.9 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.9 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.9 MB 1.6 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/9.9 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/9.9 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/9.9 MB 1.7 MB/s eta 0:00:06
#    --- ------------------------------------ 0.7/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/9.9 MB 1.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.9 MB 1.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.2/9.9 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.9 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.9 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.4/9.9 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.4/9.9 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.5/9.9 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.5/9.9 MB 1.2 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.9 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.9 MB 1.2 MB/s eta 0:00:08
#    ------ --------------------------------- 1.7/9.9 MB 1.1 MB/s eta 0:00:08
#    ------- -------------------------------- 1.8/9.9 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.9/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.0/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.2/9.9 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.3/9.9 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.9 MB 1.3 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.9 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.5/9.9 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.5/9.9 MB 1.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.9 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.7/9.9 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.8/9.9 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.8/9.9 MB 1.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.9/9.9 MB 1.3 MB/s eta 0:00:06
#    ------------ --------------------------- 3.0/9.9 MB 1.3 MB/s eta 0:00:06
#    ------------ --------------------------- 3.0/9.9 MB 1.3 MB/s eta 0:00:06
#    ------------ --------------------------- 3.0/9.9 MB 1.3 MB/s eta 0:00:06
#    ------------ --------------------------- 3.0/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 3.0/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 3.1/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 3.2/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.2/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.3/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.3/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.4/9.9 MB 1.2 MB/s eta 0:00:06
#    ------------- -------------------------- 3.5/9.9 MB 1.2 MB/s eta 0:00:06
#    -------------- ------------------------- 3.6/9.9 MB 1.2 MB/s eta 0:00:06
#    -------------- ------------------------- 3.7/9.9 MB 1.2 MB/s eta 0:00:06
#    --------------- ------------------------ 3.7/9.9 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.8/9.9 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.9/9.9 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 4.0/9.9 MB 1.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.0/9.9 MB 1.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.1/9.9 MB 1.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.1/9.9 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.9 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.3/9.9 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.4/9.9 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.4/9.9 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 4.6/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------ --------------------- 4.7/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.8/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.8/9.9 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.9/9.9 MB 1.2 MB/s eta 0:00:05
#    -------------------- ------------------- 5.0/9.9 MB 1.2 MB/s eta 0:00:04
#    -------------------- ------------------- 5.1/9.9 MB 1.2 MB/s eta 0:00:04
#    -------------------- ------------------- 5.1/9.9 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 5.2/9.9 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 5.3/9.9 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 5.4/9.9 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.4/9.9 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.9 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.6/9.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.7/9.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.8/9.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.9/9.9 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.9 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.1/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 6.1/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 6.2/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 6.2/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/9.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 6.4/9.9 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.4/9.9 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.5/9.9 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.9 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.7/9.9 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.9 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.9 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.9/9.9 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.9/9.9 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.0/9.9 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.1/9.9 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.2/9.9 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.3/9.9 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.3/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 7.4/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 7.5/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.7/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.8/9.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 8.0/9.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.2/9.9 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.2/9.9 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.3/9.9 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.3/9.9 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.4/9.9 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.5/9.9 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.5/9.9 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.6/9.9 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.9 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.8/9.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/9.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/9.9 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/9.9 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.3/9.9 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/9.9 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.5/9.9 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.6/9.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.4 MB/s eta 0:00:00
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#    ---------------------------------------- 0.0/460.2 kB ? eta -:--:--
#    -- ------------------------------------- 30.7/460.2 kB ? eta -:--:--
#    --------------- ------------------------ 174.1/460.2 kB 1.5 MB/s eta 0:00:01
#    -------------------- ------------------- 235.5/460.2 kB 1.6 MB/s eta 0:00:01
#    -------------------- ------------------- 235.5/460.2 kB 1.6 MB/s eta 0:00:01
#    --------------------------- ------------ 317.4/460.2 kB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 348.2/460.2 kB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 430.1/460.2 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 460.2/460.2 kB 1.2 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ------------------------------ --------- 92.2/121.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 121.1/121.1 kB 2.4 MB/s eta 0:00:00
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: sortedcontainers, urllib3, typing_extensions, sniffio, pysocks, pycparser, idna, h11, certifi, attrs, wsproto, outcome, cffi, trio, trio-websocket, selenium
# Successfully installed attrs-23.2.0 certifi-2024.2.2 cffi-1.16.0 h11-0.14.0 idna-3.6 outcome-1.3.0.post0 pycparser-2.21 pysocks-1.7.1 selenium-4.17.2 sniffio-1.3.0 sortedcontainers-2.4.0 trio-0.24.0 trio-websocket-0.11.1 typing_extensions-4.9.0 urllib3-2.2.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import time 
import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# # PILEG

# %%
url = "https://www.cnnindonesia.com/pemilu2024/pileg-quickcount#"
driver = webdriver.Firefox()
driver.get(url)
time.sleep(2)

all_lembaga = driver.find_element(By.CLASS_NAME, 'qc-content-tab.font-heading')
lembaga_a = all_lembaga.find_elements(By.TAG_NAME, 'a')

for lembaga in lembaga_a[4:5]:
    lembaga.click()
    time.sleep(5)

zona = driver.find_element(By.CLASS_NAME, 'qc-graph__select')
all_zona = zona.find_elements(By.TAG_NAME, 'option')

data_dict = {'province':[],
             'info':[]}

for zon in all_zona:
    zon.click()
    time.sleep(8)
    
    province = zon.text
    partai = driver.find_element(By.CLASS_NAME, 'qc-graph__list.font-heading')
    all_partai = partai.find_elements(By.TAG_NAME, 'li')

    info = driver.find_element(By.CLASS_NAME, 'qc-info.font-heading')
    time.sleep(10)

    for part in all_partai:
        all_value = part.text.split('\n')
        nama_partai = all_value[0]
        
        if nama_partai not in data_dict:
            data_dict[nama_partai] = [all_value[1]]
        else:
            data_dict[nama_partai].append(all_value[1])
    
    data_dict['info'].append(info.text.split('\n'))
    data_dict['province'].append(province)
    
    time.sleep(10)

# %% [markdown]
# # PILPRES

# %%
url = "https://www.cnnindonesia.com/pemilu2024/pilpres-quickcount"
driver = webdriver.Firefox()
driver.get(url)
time.sleep(2)

all_lembaga = driver.find_element(By.CLASS_NAME, 'qc-content-tab.font-heading')
lembaga_a = all_lembaga.find_elements(By.TAG_NAME, 'a')

for lembaga in lembaga_a[2:3]:
    lembaga.click()
    time.sleep(5)

zona = driver.find_element(By.CLASS_NAME, 'qc-graph__select')
all_zona = zona.find_elements(By.TAG_NAME, 'option')

data_dict = {'paslon':[],
             'province':[],
             'info':[]}

for zon in all_zona:
    zon.click()
    time.sleep(8)
    
    province = zon.text
    all_info = driver.find_element(By.CLASS_NAME, 'qc-pilpresgraph__graph')
    all_paslon = all_info.find_elements(By.CLASS_NAME, 'qc-pilpresgraph__graph-paslon')
    info = driver.find_element(By.CLASS_NAME, 'qc-info.font-heading')

    for paslon in all_paslon:
        nama = paslon.find_element(By.CLASS_NAME, 'qc-pilpresgraph__graph-name').text
        value = paslon.find_element(By.CLASS_NAME, 'qc-pilpresgraph__graph-value').text

        data_dict['paslon'].append(f"{nama} {value}")
        data_dict['province'].append(province)
        data_dict['info'].append(info.text.split('\n'))

    time.sleep(10)

# %%
data_dict
# Out:
# {'paslon': ['ANIES\nMUHAIMIN 79,86%',
#   'PRABOWO\nGIBRAN 18,70%',
#   'GANJAR\nMAHFUD 1,44%',
#   'ANIES\nMUHAIMIN 21,78%',
#   'PRABOWO\nGIBRAN 62,32%',
#   'GANJAR\nMAHFUD 15,90%'],
#  'province': ['ACEH',
#   'ACEH',
#   'ACEH',
#   'SUMATERA UTARA',
#   'SUMATERA UTARA',
#   'SUMATERA UTARA'],
#  'info': [['Total Data Masuk 100%', 'Terakhir Diperbarui 18:47 16/02/2024'],
#   ['Total Data Masuk 100%', 'Terakhir Diperbarui 18:47 16/02/2024'],
#   ['Total Data Masuk 100%', 'Terakhir Diperbarui 18:47 16/02/2024'],
#   ['Total Data Masuk 100%', 'Terakhir Diperbarui 18:47 16/02/2024'],
#   ['Total Data Masuk 100%', 'Terakhir Diperbarui 18:47 16/02/2024'],
#   ['Total Data Masuk 100%', 'Terakhir Diperbarui 18:47 16/02/2024']]}

# %%
data_pilkada_pileg = pd.DataFrame.from_dict(data_dict, orient="index").T
data_pilkada_pileg
# Out:
#                     paslon           province  \
# 0   ANIES\nMUHAIMIN 31,39%           Sumatera
# 1   PRABOWO\nGIBRAN 57,62%           Sumatera
# 2    GANJAR\nMAHFUD 10,99%           Sumatera
# 3   ANIES\nMUHAIMIN 30,22%         Jawa Barat
# 4   PRABOWO\nGIBRAN 60,31%         Jawa Barat
# 5     GANJAR\nMAHFUD 9,47%         Jawa Barat
# 6   ANIES\nMUHAIMIN 40,76%        DKI Jakarta
# 7   PRABOWO\nGIBRAN 41,18%        DKI Jakarta
# 8    GANJAR\nMAHFUD 18,06%        DKI Jakarta
# 9   ANIES\nMUHAIMIN 33,07%             Banten
# 10  PRABOWO\nGIBRAN 56,19%             Banten
# 11   GANJAR\nMAHFUD 10,74%             Banten
# 12  ANIES\nMUHAIMIN 13,44%  Jawa Tengah - DIY
# 13  PRABOWO\nGIBRAN 53,22%  Jawa Tengah - DIY
# 14   GANJAR\nMAHFUD 33,34%  Jawa Tengah - DIY
# 15  ANIES\nMUHAIMIN 16,49%         Jawa Timur
# 16  PRABOWO\nGIBRAN 66,50%         Jawa Timur
# 17   GANJAR\nMAHFUD 17,01%         Jawa Timur
# 18  ANIES\nMUHAIMIN 29,07%         Kalimantan
# 19  PRABOWO\nGIBRAN 59,95%         Kalimantan
# 20   GANJAR\nMAHFUD 10,97%         Kalimantan
# 21  ANIES\nMUHAIMIN 28,96%           Sulawesi
# 22  PRABOWO\nGIBRAN 62,49%           Sulawesi
# 23    GANJAR\nMAHFUD 8,55%           Sulawesi
# 24  ANIES\nMUHAIMIN 15,86%        Bali - Nusa
# 25  PRABOWO\nGIBRAN 56,91%        Bali - Nusa
# 26   GANJAR\nMAHFUD 27,23%        Bali - Nusa
# 27  ANIES\nMUHAIMIN 23,96%     Maluku - Papua
# 28  PRABOWO\nGIBRAN 56,68%     Maluku - Papua
# 29   GANJAR\nMAHFUD 19,35%     Maluku - Papua
#
#                                                  info
# 0   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 1   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 2   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 3   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 4   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 5   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 6   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 7   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 8   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 9   [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 10  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 11  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 12  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 13  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 14  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 15  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 16  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 17  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 18  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 19  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 20  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 21  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 22  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 23  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 24  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 25  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 26  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 27  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 28  [Total Data Masuk 100%, Terakhir Diperbarui 06...
# 29  [Total Data Masuk 100%, Terakhir Diperbarui 06...

# %%
data_pilkada_pileg.to_excel("quick count poltracking pilpres.xlsx")
